# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

from google.colab import userdata

#used to securely store your API key
from google.colab import userdata

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text=text.replace('.',' *')
  return Markdown(textwrap.indent(text,'> ',predicate=lambda _: True))

# %%
import os
os.environ['GOOGLE_API_KEY']="AIzaSyBTw1QHSbL1SSnv3z1m86sVxAA_VoF1gWM"
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
#gemini-pro:optimized for text only promts
#gemini-pro-vision:optimized for text and image promopts
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# ...

# %%
#Generate text from text inputs
model=genai.GenerativeModel('gemini-2.5-pro')

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.5-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %%time
response=model.generate_content("What is the meaning of life?")
# Out:
# CPU times: user 385 ms, sys: 61.2 ms, total: 446 ms
# Wall time: 31.7 s

# %%
to_markdown(response.text)
# Out:
# > That is, without a doubt, one of the oldest and most profound questions humanity has ever asked * There is no single, universally accepted answer, which is part of what makes the question so powerful * The meaning of life isn't an answer you find in a book; for many, it's something you create and live *
# >
# > Think of it less as a math problem with one solution and more as a canvas on which you paint your own picture * Here are some of the most enduring perspectives on how people approach this question *
# >
# > ### 1 * The Philosophical Lens
# >
# > Philosophers have debated this for millennia, offering various frameworks for finding meaning *
# >
# ...

# %%
response.prompt_feedback

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
response=model.generate_content("How to insult someone?")

# %%
to_markdown("response.text")
# Out:
# > response *text

# %%
response=model.generate_content("Can you let me know about the future of generative ai?")

# %%
to_markdown(response.text)
# Out:
# > Of course * The future of generative AI is one of the most exciting and debated topics in technology today * Instead of just a linear improvement, we're looking at a fundamental shift in how we interact with information, create content, and even solve problems *
# >
# > Here’s a breakdown of what the future of generative AI likely holds, from the near-term evolution to the long-term vision *
# >
# > ---
# >
# > ### The Near-Term Future (Next 1-3 Years)
# >
# > This phase is about refinement, integration, and increased accessibility * We're moving from "novelty" to "utility *"
# >
# > **1 * Seamless Multimodality:**
# > *   **What it is:** Models won't just handle text *or* images *or* audio * A single model will fluently understand, process, and generate content across all these formats simultaneously *
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %%time
response=model.generate_content("Can you let me know about the future of generative ai?",stream=True)
# Out:
# CPU times: user 523 ms, sys: 90.2 ms, total: 614 ms
# Wall time: 45.4 s

# %%
for chunk in response:
  print(chunk.text)
  print("_"*80)#we are displaying in chunks, each chunk is divided by a __
# Out:
# Of course. The future of generative
# ________________________________________________________________________________
#  AI is one of the most exciting and debated topics in technology today. It's poised to be less of a single product
# ________________________________________________________________________________
#  and more of a fundamental utility, like electricity or the internet, that will reshape countless aspects of our lives.
#
# Here’s
# ________________________________________________________________________________
#  a breakdown of what the future of generative AI likely holds, covering the technological trends, the impact on society, and the critical
# ________________________________________________________________________________
#  challenges we'll face.
#
# ---
#
# ### Part 1: Key Technological Trends (What the AI Will Do)
#
# The generative
# ________________________________________________________________________________
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
response.prompt_feedback

# %%
# %%time
response=model.generate_content("What the top5 outdoor sports/games olayed in India?",stream=True)
# Out:
# CPU times: user 401 ms, sys: 68.9 ms, total: 470 ms
# Wall time: 33.9 s

# %%
try:
  response.text
except Exception as e:
  print(f'{type(e).__name__}:{e}')
# Out:
# IncompleteIterationError:Please let the response complete iteration before accessing the final accumulated
# attributes (or call `response.resolve()`)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#gemini-pro-vision

# %%
import PIL.Image
img=PIL.Image.open('/rice_disease.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=276x183>

# %%
model=genai.GenerativeModel('gemini-2.5-flash')

# %%
response=model.generate_content(img)
to_markdown(response.text)
# Out:
# > The image shows **Rice False Smut**, a common fungal disease affecting rice crops *
# >
# > Here's a breakdown:
# >
# > 1 *  **What you see:** Roundish, swollen, orange-brown to greenish-black structures appearing on individual rice grains within the panicle * These are "smut balls" or sori, which are essentially masses of fungal spores *
# > 2 *  **Causative Agent:** The disease is caused by the fungus *Ustilaginoidea virens* (the anamorph) or *Claviceps oryzae-sativae* (the teleomorph) *
# > 3 *  **Symptoms:**
# >     *   Initially, infected individual grains develop into yellowish, velvety smut balls *
# >     *   As the disease progresses, these balls enlarge and change color to orange, then olive-green, and finally greenish-black due to the maturation of millions of chlamydospores (fungal spores) *
# >     *   The smut balls often rupture, releasing a powdery mass of spores *
# ...

# %%
response=model.generate_content("Give a short blogpost of the health of the Rice crop? Also tell me what soil type and weather conditions is helpful for this specific crop cultivation?You answers should be accurate and in bullets with attractuve formatting.")

# %%
to_markdown(response.text)
# Out:
# > ## The Green Gold: A Pulse Check on the World's Rice Fields
# >
# > Rice, the staple food for over half the global population, is more than just a grain; it's a lifeline * So, how's this vital crop faring globally? Let's take a quick look at its health and the conditions that help it flourish *
# >
# > ---
# >
# > ### The Pulse of the Paddy: A Snapshot of Rice Health
# >
# > Overall, the global rice crop is remarkably resilient, a testament to ongoing agricultural advancements * However, even this "green gold" faces its share of challenges *
# >
# > *   **Generally Robust:** Many regions report healthy crops, characterized by lush green leaves, strong tillering (branching), and robust grain development, promising good yields *
# > *   **Persistent Threats:** Rice health is constantly battled by:
# >     *   **Pests:** Insect infestations like **brown planthoppers**, **stem borers**, and **leaf folders** can cause significant damage if not managed *
# ...
